# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from autotst.species import Conformer

#from autotst.molecule import AutoTST_Molecule
#from ase.io import write
import ase
from ase.calculators.gaussian import *
#from autotst.calculators.gaussian import AutoTST_Gaussian
import subprocess
import shlex
from subprocess import call
from shlex import split
from ase.io.gaussian import read_gaussian_out
from rmgpy.molecule import Molecule as RMGMolecule

# %%
# Writing Geo opt input as AutoTST would

from autotst.species import Conformer
from ase.calculators.gaussian import *
test_mol = Conformer('CCCC(=O)OC')

# Preparing gaussian input file parameters for Geo Opt as AutoTST does it
test_g = Gaussian()
test_g.label = test_mol.rmg_molecule.toAugmentedInChIKey() + '_Geo'
print test_g.label + '.com'
print
test_g.parameters['method'] = 'm062x'
test_g.parameters['basis'] = '6-311+g(2df,2p)'
test_g.extra = 'opt=(calcfc,maxcycle=1000)'
del test_g.parameters['force']

# Checking parameters are good
for key, val in test_g.parameters.items():
    print key, val

# Write geo input file
test_g.write_input(test_mol.ase_molecule)
test_mol.view()

# %%
#subprocess.call(shlex.split('sbatch rotors_run_template.sh {0}'.format(geo_filename)))

# %%
SML = 'CC(CO)(C)OC'
a = TS_Species(smiles=[SML])
b = fake_statmech()
b.write_arkane_for_reacts_and_prods(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-78239a9e1e14> in <module>()
#       2 a = TS_Species(smiles=[SML])
#       3 b = fake_statmech()
# ----> 4 b.write_arkane_for_reacts_and_prods(a)
#
# <ipython-input-53-131b384dec4a> in write_arkane_for_reacts_and_prods(self, species)
#      60
#      61
# ---> 62         with open(os.path.join(self.scratch, label +".py"), "w") as f:
#      63             f.write(input_string)
#      64
#
# AttributeError: fake_statmech instance has no attribute 'scratch'

# %%
from autotst.species import Species as TS_Species
from autotst.species import Conformer
from rdkit import Chem
import os

class fake_statmech():
    def __init__(self):
        self.model_chemistry = "oops"
        return
        
    def write_arkane_for_reacts_and_prods(self, species):
        """
        a method to write species to an arkane input file. Mol is an RMGMolecule
        """

        conf = Conformer(species.smiles[0])

        mol = conf.rmg_molecule


        output = ['#!/usr/bin/env python',
                  '# -*- coding: utf-8 -*-', '', 'atoms = {']

        atom_dict = self.get_atoms(species)

        for atom, count in atom_dict.iteritems():
            output.append("    '{0}': {1},".format(atom, count))
        output = output + ['}', '']

        bond_dict = self.get_bonds(species)
        if bond_dict != {}:
            output.append('bonds = {')
            for bond_type, num in bond_dict.iteritems():
                output.append("    '{0}': {1},".format(bond_type, num))
            output.append("}")
        else:
            output.append('bonds = {}')

        label = Chem.rdinchi.InchiToInchiKey(
            Chem.MolToInchi(Chem.MolFromSmiles(mol.toSMILES()))).strip("-N")

        external_symmetry = mol.getSymmetryNumber()

        output += ["", "linear = False", "", "externalSymmetry = {}".format(external_symmetry), "",
                   "spinMultiplicity = {}".format(mol.multiplicity), "", "opticalIsomers = 1", ""]

        output += ["energy = {", "    '{0}': Log('{1}.log'),".format(
            self.model_chemistry, label), "}", ""]

        output += ["geometry = Log('{0}.log')".format(label), ""]

        output += [
            "frequencies = Log('{0}.log')".format(label), ""]

        output += ["rotors = []"]

        input_string = ""

        for t in output:
            input_string += t + "\n"


        with open(os.path.join(os.getcwd(), label +".py"), "w") as f:
            f.write(input_string)
            
    def get_atoms(self, species):
        """
        A method to create an atom dictionary for an rmg molecule
        """
        atom_dict = {}

        conf = Conformer(species.smiles[0])

        rmg_mol = conf.rmg_molecule

        for atom in rmg_mol.atoms:
            if atom.isCarbon():
                atom_type = "C"
            if atom.isHydrogen():
                atom_type = "H"
            if atom.isOxygen():
                atom_type = "O"

            try:
                atom_dict[atom_type] += 1
            except KeyError:
                atom_dict[atom_type] = 1

        return atom_dict

    def get_bonds(self, species):


        conf = Conformer(species.smiles[0])

        rmg_mol = conf.rmg_molecule

        bondList = []
        for atom in rmg_mol.atoms:
            for bond in atom.bonds.values():
                bondList.append(bond)
        bonds = list(set(bondList))
        bondDict = {}
        for bond in bonds:
            if bond.isSingle():
                if bond.atom1.symbol == 'C' and bond.atom2.symbol == 'C':
                    bondType = 'C-C'
                elif (bond.atom1.symbol == 'H' and bond.atom2.symbol == 'H'):
                    bondType = 'H-H'
                elif (bond.atom1.symbol == 'C' and bond.atom2.symbol == 'H') or (bond.atom1.symbol == 'H' and bond.atom2.symbol == 'C'):
                    bondType = 'C-H'
                elif (bond.atom1.symbol == 'O' and bond.atom2.symbol == 'O'):
                    bondType = 'O-O'
                elif (bond.atom1.symbol == 'C' and bond.atom2.symbol == 'O') or (bond.atom1.symbol == 'O' and bond.atom2.symbol == 'C'):
                    bondType = 'C-O'
                elif (bond.atom1.symbol == 'H' and bond.atom2.symbol == 'O') or (bond.atom1.symbol == 'O' and bond.atom2.symbol == 'H'):
                    bondType = 'O-H'
                elif bond.atom1.symbol == 'N' and bond.atom2.symbol == 'N':
                    bondType = 'N-N'
                elif (bond.atom1.symbol == 'C' and bond.atom2.symbol == 'N') or (bond.atom1.symbol == 'N' and bond.atom2.symbol == 'C'):
                    bondType = 'N-C'
                elif (bond.atom1.symbol == 'O' and bond.atom2.symbol == 'N') or (bond.atom1.symbol == 'N' and bond.atom2.symbol == 'O'):
                    bondType = 'N-O'
                elif (bond.atom1.symbol == 'H' and bond.atom2.symbol == 'N') or (bond.atom1.symbol == 'N' and bond.atom2.symbol == 'H'):
                    bondType = 'N-H'
                elif bond.atom1.symbol == 'S' and bond.atom2.symbol == 'S':
                    bondType = 'S-S'
                elif (bond.atom1.symbol == 'H' and bond.atom2.symbol == 'S') or (bond.atom1.symbol == 'S' and bond.atom2.symbol == 'H'):
                    bondType = 'S-H'
            elif bond.isDouble:
                if bond.atom1.symbol == 'C' and bond.atom2.symbol == 'C':
                    bondType = 'C=C'
                elif (bond.atom1.symbol == 'O' and bond.atom2.symbol == 'O'):
                    bondType = 'O=O'
                elif (bond.atom1.symbol == 'C' and bond.atom2.symbol == 'O') or (bond.atom1.symbol == 'O' and bond.atom2.symbol == 'C'):
                    bondType = 'C=O'
                elif bond.atom1.symbol == 'N' and bond.atom2.symbol == 'N':
                    bondType = 'N=N'
                elif (bond.atom1.symbol == 'C' and bond.atom2.symbol == 'N') or (bond.atom1.symbol == 'N' and bond.atom2.symbol == 'C'):
                    bondType = 'N=C'
                elif (bond.atom1.symbol == 'O' and bond.atom2.symbol == 'N') or (bond.atom1.symbol == 'N' and bond.atom2.symbol == 'O'):
                    bondType = 'N=O'
                elif (bond.atom1.symbol == 'O' and bond.atom2.symbol == 'S') or (bond.atom1.symbol == 'S' and bond.atom2.symbol == 'O'):
                    bondType = 'S=O'
            elif bond.isTriple:
                if bond.atom1.symbol == 'C' and bond.atom2.symbol == 'C':
                    bondType = 'C#C'
                elif bond.atom1.symbol == 'N' and bond.atom2.symbol == 'N':
                    bondType = 'N#N'
                elif (bond.atom1.symbol == 'C' and bond.atom2.symbol == 'N') or (bond.atom1.symbol == 'N' and bond.atom2.symbol == 'C'):
                    bondType = 'N#C'
            try:
                bondDict[bondType] += 1
            except KeyError:
                bondDict[bondType] = 1

        return bondDict

# %%
from autotst.species import Species as TS_Species
a = TS_Species(smiles=['CC'])
from autotst.calculators.statmech import StatMech

rxn = 'faux rxn'
b = StatMech(rxn)
b.write_arkane_for_reacts_and_prods(a)
# Out:
# statmech.py:68 find_lowest_energy_conformer INFO Output log files don't exist for <Conformer "CC">
# statmech.py:68 find_lowest_energy_conformer INFO Output log files don't exist for <Conformer "CC">
# statmech.py:68 find_lowest_energy_conformer INFO Output log files don't exist for <Conformer "CC">

# %%
glog = 'VMPUAIZSESMILD-UHFFFAOYSA-N_tor17.log'
x = arkane.gaussian.GaussianLog(glog)
len(x.loadScanEnergies()[1])
plt.plot(x.loadScanEnergies()[1],x.loadScanEnergies()[0])
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-a18606cb998d> in <module>()
# ----> 1 mol
#
# NameError: name 'mol' is not defined

# %%
g = arkane.gaussian.GaussianLog('VMPUAIZSESMILD-UHFFFAOYSA-N_tor17.log')
g
# Out:
# <arkane.gaussian.GaussianLog instance at 0x2b1f400fa908>

# %%
g.loadEnergy()
# Out:
# -914073878.6136136

# %%
import arkane
import cclib
from ase.io.gaussian import read_gaussian_out
from rmgpy.molecule import Molecule as RMGMolecule
from ase.calculators.gaussian import *
import matplotlib.pyplot as plt
import numpy as np

class hindered_rotors:
    
    def __init__(self, SMILES, Label=None, default=True):
        if type(SMILES) == str:
            self.SMILES = SMILES
            self.label = None
            self.rmgMOL = None
            self.geoIsOpt = False
            #self.rmgMOL.fromSMILES(SMILES)
            tmpMol = RMGMolecule()
            tmpMol.fromSMILES(SMILES)
            self.AugInchiKey = tmpMol.toAugmentedInChIKey()
            
            #Atom indices must start from 1!!! (As Gaussain does but not others)
            self.torsions = None
            
            self.scansUpdated = False
            self.scans = []
            
            if default:
                self.updateMol()
                self.set_torsions()
                self.set_scans(36, 10.0)
                self.update_scans()
            return
    #def write geo_opt file

    def updateMol(self, geo_file=None):
        if geo_file==None:
            geo_file = self.AugInchiKey + '_Geo.log'
        
        try:
            atoms = read_gaussian_out(geo_file)
        except:
            assert False, "Failed to find valid geo_file"
        
        #Update XYZ
        mol = RMGMolecule()
        mol.fromXYZ(atoms.get_atomic_numbers(), atoms.get_positions())
        
        #Update IDs
        i = 1
        for atom in mol.atoms:
            atom.id = i
            i = i + 1
        
        #Update Multiplicity
        mol.updateMultiplicity()
        self.rmgMOL = mol
        self.geoIsOpt = True
        return
            
    def set_torsions(self, geoIsOpt=None):
        """
        Method setting torsions of simple chains to hindered rotors object

        NO RINGS
        NO RINGS
        NO RINGS

        A - Bond1 - B - Bond2 - C - Bond3 - D

        i = A.index
        j = B.index
        k = C.index
        l = D.index

        Torsion is unique if j,k & k,j pairing is unique

        """
        mol = self.rmgMOL
        if not geoIsOpt:
            #Most important is that IDs are labelled as they would appear to gaussian
            #Gaussian starts indexing at 1. Weird, right?
            i = 1
            for atom in mol.atoms:
                atom.id = i
                i = i + 1
            
        # dict of (j, k) key with [i,j,k,l] value
        # Wipes existing torsions away to recalculate
        self.torsions = {}
            
        for bond2 in mol.getAllEdges():
            i, j, k, l = -1,-1,-1,-1
            B = bond2.atom1
            j = bond2.atom1.id

            C = bond2.atom2
            k = bond2.atom2.id

            assert (j,k) not in self.torsions.keys() #: #or [k,j] in torsions.keys():
            # [i,j,k,l] and [i,j,k,m] torsion is the same to Gaussian as long as center is k&j or j&k
            #continue

            found_bond1 = False
            found_bond3 = False

            for Bbond in mol.getBonds(B).values():
                if (Bbond.atom1.id == B.id) and (Bbond.atom2.id != C.id):
                    #Bbond is not bond2
                    #Bbond must be bond1
                    found_bond1 = True
                    i = Bbond.atom2.id
                elif (Bbond.atom1.id != C.id) and (Bbond.atom2.id == B.id):
                    #Bbond is not bond2
                    #Bbond must be bond1
                    found_bond1 = True
                    i = Bbond.atom1.id
                else:
                    #Bbond is bond2
                    assert (Bbond.atom1 == C) or (Bbond.atom2 == C)

            for Cbond in mol.getBonds(C).values():
                if (Cbond.atom1.id == C.id) and (Cbond.atom2.id != B.id):
                    #Bbond is not bond2
                    #Bbond must be bond3
                    found_bond3 = True
                    l = Cbond.atom2.id
                elif (Cbond.atom1.id != B.id) and (Cbond.atom2.id == C.id):
                    #Bbond is not bond2
                    #Bbond must be bond1
                    found_bond3 = True
                    l = Cbond.atom1.id
                else:
                    #Cbond is bond2
                    assert (Cbond.atom1 == B) or (Cbond.atom2 == B)

            #print found_bond1, found_bond3
            #print i, j, k, l
            #print
            if found_bond1 and found_bond3:
                self.torsions[(j,k)] = [i,j,k,l]
        return
    
    def set_scans(self, steps, stepsize, use_defaults=True):
        """
        Sets the scans[] list of object
        """
        assert self.torsions is not None
        
        isOptGeo = self.geoIsOpt
        torsions = self.torsions
        RMGmol = self.rmgMOL
        
        assert type(steps) is int
        assert type(stepsize) is float
    
        #One scan for every torsion
        if isOptGeo:
            for center, torsion in torsions.items():
                scan_inst = scan(RMGmol, torsion, steps, stepsize, defaults=use_defaults)
                self.scans.append(scan_inst)
        return
        
    def update_scans(self):
        self.scansUpdated = True
        
        for scan in self.scans:
            got_data = scan.get_data()
            self.scansUpdated = self.scansUpdated and got_data
        
        return self.scansUpdated
    def Rote_write_geo_com(self, filename=None):
        """
        Writes Gaussian input file for a geometry optimization of self.rmgMol
        with a basisand parameters similar to AutoTST
        """
        if filename is None:
            filename = self.AugInchiKey + '_Geo.com'

        # Preparing gaussian input file parameters for Geo Opt as AutoTST does it
        g_inst = Gaussian()
        g_inst.label = self.AugInchiKey + '_Geo'
        
        g_inst.parameters['method'] = 'm062x'
        g_inst.parameters['basis'] = '6-311+g(2df,2p)'
        g_inst.extra = 'opt=(calcfc,maxcycle=1000)'
        del g_inst.parameters['force']

        # Write Gaussian input file
        test_g.write_input(test_mol.ase_molecule)
        

class scan:
    
    def __init__(self, RMGmol, torsion, steps, stepsize, defaults=True):
        #print type(RMGmol)
        #assert type(RMGmol) == RMGMolecule()
        self.rmgMOL = RMGmol
        self.AugInchiKey = self.rmgMOL.toAugmentedInChIKey()
        
        self.i = torsion[0]
        self.j = torsion[1]
        self.k = torsion[2]
        self.l = torsion[3]
        
        self.steps = steps
        self.stepsize = stepsize
        
        self.geo_log = None
        self.input_com = None
        self.output_log = None
        
        #After running a scan, populate data
        self.data = None
        
        self.opt_indices = None
        self.start_indices = None
        self.opt_scfenergies = None
        self.atomcoords = None
        
        self.label = None
        
        if defaults:
            self.set_default_files()

    def set_default_files(self):
        self.geo_log = self.AugInchiKey + '_Geo.log'

        j = self.j
        k = self.k
        
        a = min([j, k])
        b = max([j, k])
        
        self.input_com = self.AugInchiKey + '_tor{}{}'.format(a, b) + '.com'
        self.output_log = self.AugInchiKey + '_tor{}{}'.format(a, b) + '.log'
        return
    
    def Rote_write_input(self, filename=None, options=None):
        """
        Given filename and options, and taking RMGMolecule object from scan
        Write input file for torsion of scan
        """
        if filename is None:
            filename = self.input_com
            torsion = self.torsion
        
        mol = self.rmgMOL
        mol.updateMultiplicity()
        
        if options is None:
            options = ['%nprocshared=20',
                       '%mem=5GB',
                       '#p m062x/6-311+g(2df,2p) Opt=(CalcFC,ModRedun)']
        
        output = '\n'.join(Options)
        output = '\n'.join(['','','0 {}'.format(mol.multiplicity),''])
        
        n = 1
        for atom in mol.atoms:
            assert n == atom.id
            n = n + 1
            output = output + "{}     {}     {}     {}\n".format(atom.element, atom.coords[0], atom.coords[1], atom.coords[2])

        output = output + '\n'

        for bond in mol.getAllEdges():
            output = output + 'B {0} {1}\n'.format(bond.atom1.id, bond.atom2.id)

        output = output + 'D {0} {1} {2} {3} S {4} {5}'.format(torID[0],
                                                               torID[1],
                                                               torID[2],
                                                               torID[3],
                                                               nsteps,
                                                               stepsize)
        output = output + '\n\n\n'
        #print output
        
        a = min([torsion[1], torsion[2]])
        b = max([torsion[1], torsion[2]])
        tor_file = self.AugInchiKey + '_tor{0}{1}'.format(a,b) + '.com'
        #print tor_file
        F = open(tor_file, 'w')
        assert not F.closed
        F.write('')
        F.write(output)
        #print F
        F.close
        return
    
    def get_data(self, data_log=None):
        """
        Populating scan data attributes from gaussian scan output log
        """
        if data_log is None:
            data_log = self.output_log
        
        try:
            self.data = cclib.io.ccread(data_log)
        except:
            #Failed to read data log. Could be file does not exist or not in proper directory
            return False
        
        # TODO change to get from log
        start_idx = []
        self.opt_indices = [i for i, status in enumerate(self.data.optstatus) if status==2]
        self.start_indices = [i for i, status in enumerate(self.data.optstatus) if status==1]
        self.opt_scfenergies = [self.data.scfenergies[index] for index in self.opt_indices]
        
        
        assert len(self.opt_indices) == self.steps + 1
        assert len(self.start_indices) == self.steps + 1
        assert len(self.opt_scfenergies) == self.steps + 1
        
        #Keeping atomcoords organized with their respective atom nos for easy ID
        atom_id_coords = []
        atomids = self.data.atomnos
        for i, geo_coords in enumerate(self.data.atomcoords):
            #Setting up [atomno, x, y, x] for each atom in a geometry
            geo_id_coords = np.insert(geo_coords, 0, atomids, axis=1)
            #Adding all of individual geometries to master list
            atom_id_coords.append(geo_id_coords)
        
        self.atomcoords = atom_id_coords
        
        return
    
    def plot_scan(self):
        thetas = [self.stepsize*i for i in range(self.steps+1)]
        
        plt.plot(thetas, self.opt_scfenergies)
    
    def check_theta_continuous(self, tol=None):
        """
        Returns true if scfenergies at the same theta are within tolerance
        
        Must populate:
        self.opt_scfenergies
        self.steps
        self.stepsize
        
        """
        if tol is None:
            tol = 10**-8
        
        energy_by_theta = {}
        rot = 0
        for energy in self.opt_scfenergies:
            #Assumes stepsize given in degrees
            #Assume thetas varying by more than a degree are different (see slope_continous)
            theta = int(rot%360)
            
            if theta in energy_by_theta.keys():
                previous = energy_by_theta[theta]
                error = 1.00000-previous/energy
                
                if (error > tol) or (error < -tol):
                    return False
            else:
                energy_by_theta[theta] = energy
            
            rot = rot + self.stepsize
        return True
    
    def check_slope_continuous(self, tol=None):
        """
        Check if change in energy within given tolerance over opt scf energies
        
        Must populate:
        self.opt_scfenergies
        self.steps
        self.stepsize
        
        """
        if tol is None:
            tol = 10**-2.5
        
        for i in range(1, len(self.opt_scfenergies)):
            slope = (self.opt_scfenergies[i]-self.opt_scfenergies[i-1])/self.stepsize
            print slope
            if slope>tol:
                return False
        
        return True

# %%
#hin_inst = hindered_rotors('CCCC(=O)OC')
hin_inst = hindered_rotors('CC(CO)(C)OC', default=False)
hin_inst.updateMol()
hin_inst.set_torsions()
hin_inst.set_scans(36, 10.0)

for tor_scan in hin_inst.scans:
    tor_scan.get_data()
    print tor_scan.j, tor_scan.k
    print tor_scan.geo_log
    print tor_scan.input_com
    print tor_scan.output_log
    break
# Out:
# 7 1
# VMPUAIZSESMILD-UHFFFAOYSA-N_Geo.log
# VMPUAIZSESMILD-UHFFFAOYSA-N_tor17.com
# VMPUAIZSESMILD-UHFFFAOYSA-N_tor17.log

# %%
data=tor_scan.data
steps = 36
theta = 10.0

opt_indices = [i for i, status in enumerate(data.optstatus) if status==2]
opt_energies = [data.scfenergies[index] for index in opt_indices]
len(opt_energies)

thetas = [i*theta for i in range(steps+1)]
plt.plot(thetas, opt_energies)
#plt.plot(opt_energies)
plt.show()

# %%
from rmgpy.molecule import Molecule as RMGMolecule
from ase.io.gaussian import read_gaussian_out

# Given dict of number of torsion steps, step size (degrees) by key of optimized geometry file
# Writes gaussian scan input files for every torsion


SMILES = 'CC(CO)(C)OC'
tmpMol = RMGMolecule()
tmpMol.fromSMILES(SMILES)
opt_geo_file = tmpMol.toAugmentedInChIKey() + '_Geo.log'
steps = 36
stpsize = 10.0
geo_to_tor_input = {}
geo_to_tor_input[opt_geo_file] = [SMILES, steps, stpsize]

print SMILES
print tmpMol.toAugmentedInChIKey()
print opt_geo_file
print steps
print stpsize
print

for opt_geo_file in geo_to_tor_input:
    SMILES, nsteps, stepsize = geo_to_tor_input[opt_geo_file]

    atoms = read_gaussian_out(opt_geo_file)
    #ase.io.write('test.xyz', atoms)
    mol = RMGMolecule()
    mol.fromXYZ(atoms.get_atomic_numbers(), atoms.get_positions())
    
    #Does not work for anything other than chains of singles bonds

    #Need to assign atom IDs in order of appearance
    i = 1
    for atom in mol.atoms:
        atom.id = i
        i= i + 1
    
    """
    A - Bond1 - B - Bond2 - C - Bond3 - D

    i = A.index
    j = B.index
    k = C.index
    l = D.index

    Torsion is unique if j,k & k,j pairing is unique

    """
    
    
    #Dict of [i,j,k,l] with (j,k) key
    torsions = {}
    i, j, k, l = -1,-1,-1,-1
    #for atom in mol1.atoms:
    #    for bond2 in mol1.getBonds(atom).values():
    for bond2 in mol.getAllEdges():
        B = bond2.atom1
        j = bond2.atom1.id

        C = bond2.atom2
        k = bond2.atom2.id

        assert (j,k) not in torsions.keys() #: #or [k,j] in torsions.keys():
        # [i,j,k,l] and [i,j,k,m] torsion is the same to Gaussian as long as center is k&j or j&k
        #continue

        found_bond1 = False
        found_bond3 = False

        for Bbond in mol.getBonds(B).values():
            if (Bbond.atom1.id == B.id) and (Bbond.atom2.id != C.id):
                #Bbond is not bond2
                #Bbond must be bond1
                found_bond1 = True
                i = Bbond.atom2.id
            elif (Bbond.atom1.id != C.id) and (Bbond.atom2.id == B.id):
                #Bbond is not bond2
                #Bbond must be bond1
                found_bond1 = True
                i = Bbond.atom1.id
            else:
                #Bbond is bond2
                assert (Bbond.atom1 == C) or (Bbond.atom2 == C)
                
        for Cbond in mol.getBonds(C).values():
            if (Cbond.atom1.id == C.id) and (Cbond.atom2.id != B.id):
                #Bbond is not bond2
                #Bbond must be bond3
                found_bond3 = True
                l = Cbond.atom2.id
            elif (Cbond.atom1.id != B.id) and (Cbond.atom2.id == C.id):
                #Bbond is not bond2
                #Bbond must be bond1
                found_bond3 = True
                l = Cbond.atom1.id
            else:
                #Cbond is bond2
                assert (Cbond.atom1 == B) or (Cbond.atom2 == B)
                        
        #print found_bond1, found_bond3
        #print i, j, k, l
        #print
        if found_bond1 & found_bond3:
            torsions[(j,k)] = [i,j,k,l]

    
    
    for torCore in torsions:
        torID = torsions[torCore]
        mol.updateMultiplicity()
        output = '\n'.join(['%nprocshared=20',
                            '%mem=5GB',
                            '#p m062x/6-311+g(2df,2p) Opt=(CalcFC,ModRedun)',
                            '',
                            'Gaussian input prepared with RMG/Hands',
                            '',
                            '0 {}'.format(mol.multiplicity),
                            ''])
        n = 1
        for atom in mol.atoms:
            assert n == atom.id
            n = n + 1
            output = output + "{}     {}     {}     {}\n".format(atom.element, atom.coords[0], atom.coords[1], atom.coords[2])

        output = output + '\n'

        for bond in mol.getAllEdges():
            output = output + 'B {0} {1}\n'.format(bond.atom1.id, bond.atom2.id)

        output = output + 'D {0} {1} {2} {3} S {4} {5}'.format(torID[0],
                                                                  torID[1],
                                                                  torID[2],
                                                                  torID[3],
                                                                  nsteps,
                                                                  stepsize)
        output = output + '\n\n\n'
        #print output
        
        tmpMol = RMGMolecule()
        tmpMol.fromSMILES(SMILES)
        a = min([torID[1], torID[2]])
        b = max([torID[1], torID[2]])
        tor_file = tmpMol.toAugmentedInChIKey() + '_tor{0}{1}'.format(a,b) + '.com'
        print tor_file
        F = open(tor_file, 'w')
        assert not F.closed
        F.write('')
        F.write(output)
        #print F
        F.close
# Out:
# CC(CO)(C)OC
# VMPUAIZSESMILD-UHFFFAOYSA-N
# VMPUAIZSESMILD-UHFFFAOYSA-N_Geo.log
# 36
# 10.0
#
# VMPUAIZSESMILD-UHFFFAOYSA-N_tor17.com
# VMPUAIZSESMILD-UHFFFAOYSA-N_tor13.com
# VMPUAIZSESMILD-UHFFFAOYSA-N_tor36.com
# VMPUAIZSESMILD-UHFFFAOYSA-N_tor34.com
# VMPUAIZSESMILD-UHFFFAOYSA-N_tor24.com
# VMPUAIZSESMILD-UHFFFAOYSA-N_tor35.com

# %%
for bond in mol.getAllEdges():
    print bond.atom1.id , bond.atom1, bond.atom2, bond.atom2.id

# %%
import subprocess, shlex
base_filename = 'VMPUAIZSESMILD-UHFFFAOYSA-N_tor17'
subprocess.call(shlex.split('sbatch rotors_run_template.sh {0}'.format(base_filename)))

# %%
# Creating Sample Molecule: n-Butanol
tor_mol = AutoTST_Molecule("CCCCO")




### Rest of code generalized around tor_mol input
# Updating n-Butanol from previous optimization
OptGeo_filename = tor_mol.rmg_molecule.toAugmentedInChIKey() + '_Geo.log'
OptGeo_filename = 'MethylPropanoate.log'
tor_mol.ase_molecule = read_gaussian_out(OptGeo_filename)
tor_mol.update_from_ase_mol()

# Getting caculator instances for each torsion in mol
auto_gaus = AutoTST_Gaussian()
calcs = auto_gaus.get_rotor_calc(autotst_object=tor_mol)
# Iterating to run each torsion
for torsions in calcs:
    # Get rotor calculator
    rotor_calc = calcs[torsions]
    input_filename = rotor_calc.label
    
    # Create input file
    #rotor_calc.write_input(mol.ase_molecule)
    
    """
    # Old method of creating unique run-script for each torsion
    # Create run-script
    rotors_runscript_template = "#!/bin/bash\n\n#SBATCH --job-name={0}\n#SBATCH --output={0}.log\n\n## number of nodes\n#SBATCH -N 1\n#SBATCH --exclusive\n#SBATCH --partition=general\n#SBATCH --mem=120000\n\n## set the gaussian scratch directory to a fast drive\n## note that /tmp/ may be even faster than /gss_gpfs_scratch/\n#export GAUSS_SCRDIR=/scratch/$USER/gaussian_scratch\n## make the directory if it doesn't exist already\n#mkdir -p $GAUSS_SCRDIR\n\n# run gaussian, with the desired input file\ng16 {0}.com"
    run_script = open(input_filename + '.sh', "w")
    run_script.write(run_script_template.format(input_file_name))
    run_script.close()
    """
    
    # Call run-script with filename passed on as parameter
    #subprocess.call(shlex.split('sbatch rotors_run_template.sh {0}'.format(input_filename)))

    #print "Running {0}".format(input_filename)
    

    #auto_guas.calculate(mol, rotor_calc)

'Done'

# %%
# To create new template run-script

#rotors_runscript_template = "#!/bin/bash\n\n#SBATCH --job-name=$1\n#SBATCH --output=$1.log\n\n## number of nodes\n#SBATCH -N 1\n#SBATCH --exclusive\n#SBATCH --partition=general\n#SBATCH --mem=120000\n\n## set the gaussian scratch directory to a fast drive\n## note that /tmp/ may be even faster than /gss_gpfs_scratch/\n#export GAUSS_SCRDIR=/scratch/$USER/gaussian_scratch\n## make the directory if it doesn't exist already\n#mkdir -p $GAUSS_SCRDIR\n\n# run gaussian, with the desired input file\ng16 $1.com\n\n"

lst_template = ["#!/bin/bash",
                "",
                "#SBATCH --job-name=rotor",
                "#SBATCH --output=$1.log",
                "",
                "## number of nodes",
                "#SBATCH -N 1",
                "#SBATCH --exclusive",
                "#SBATCH --partition=general",
                "#SBATCH --mem=120000",
                "",
                "## export GAUSS_SCRDIR=/scratch/$USER/gaussian_scratch",
                "## make the directory if it doesn't exist already",
                "## mkdir -p $GAUSS_SCRDIR",
                "",
                "# run gaussian, with the desired input file",
                "g16 $1.com",
                "",
                ""]

#new_script_template = open('rotors_run_template.sh', 'w')
#new_script_template.write('\n'.join(lst_template))
print '\n'.join(lst_template)
#new_script_template.close()
#print rotors_runscript_template

# %%
mol = AutoTST_Molecule("CCCCO")
#mol.ase_molecule
mol.ase_molecule = read_gaussian_out("test.log")
mol.ase_molecule = read_gaussian_out("LRHPLDYGYMQRHN-UHFFFAOYSA_tor01.log")
#mol.update_from_ase_mol()

# %%
subprocess.call(shlex.split('./low_impact_script.sh CCCC)'))

# %%
#!/bin/bash

#SBATCH --job-name={}
#SBATCH --output={}.log

## number of nodes
#SBATCH -N 1
#SBATCH --exclusive
#SBATCH --partition=general
#SBATCH --mem=120000

## set the gaussian scratch directory to a fast drive
## note that /tmp/ may be even faster than /gss_gpfs_scratch/
#export GAUSS_SCRDIR=/gss_gpfs_scratch/$USER/gaussian_scratch
## make the directory if it doesn't exist already
#mkdir -p $GAUSS_SCRDIR

# run gaussian, with the desired input file
g16 {}.com

# %%
rotor_calc.write_input??

# %%
# Creating Gaussian input file

g = Gaussian()
g.label = "test"
g.write_input(mol.ase_molecule)

# %%
# Creating xyz file
ase.io.write("{}.xyz".format(mol.smiles), mol.ase_molecule)

# %%
import subprocess

# %%
# Practicing my subprocess calls
#subprocess.call(shlex.split('./low_impact_script.sh filename'))

#subprocess.call(shlex.split('sbatch low_impact_script.sh filename'))

# %%
scripts_to_run = ['low_impact_script.sh', 'low_impact_script2.sh']
#scripts_to_run = ['low_impact_script.sh']
print scripts_to_run
for script in scripts_to_run:
    str = './{} param1 param2'.format(script)
    print str
    #subprocess.call(shlex.split('./{} param1 param2'.format(script)))
